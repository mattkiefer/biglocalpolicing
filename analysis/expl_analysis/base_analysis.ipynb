# %% [markdown]
# # Base Analysis

# %% [markdown]
# ### Setup

# %% [markdown]
# #### Load Libraries

# %%
library(tidyverse)
library(lubridate)
library(sf)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.2.0     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.2
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘lubridate’
#
# The following object is masked from ‘package:base’:
#
#     date
#
# Linking to GEOS 3.6.1, GDAL 2.1.3, PROJ 4.9.3

# %% [markdown]
# #### Parameters

# %%
## First save csv files into a folder called data within your working directory

census_path <- "data/ACS_15_5YR_B02001.csv.zip"
nd_path <- "data/nd_statewide_2019_08_13.csv.zip"
wa_path <- "data/wa_statewide_2019_08_13.csv"
county_shapefiles_path <- "data/tl_2016_us_county/tl_2016_us_county.shp"
#wa_path_2 <- "wa_statewide_2019_08_13.csv"

nd_state_fip <- 38

# %% [markdown]
# #### Load Data

# %%
census_data <-
    census_path %>%
    read_csv(skip = 1) %>%
    select(
        geography = Geography, 
        total_pop = `Estimate; Total:`, 
        total_na = `Estimate; Total: - American Indian and Alaska Native alone`
    ) %>%
    separate(geography, c("county", "state"), sep = ", ", remove = FALSE) %>%
    mutate(
        na_pop_prop = (total_na/total_pop) * 100,
        state = state %>% str_to_lower(),
        county = county %>% str_to_lower()
    )

county_shapefiles_data <-
    county_shapefiles_path %>%
    st_read() %>%
    rename(county = "NAMELSAD")

nd_data <-
    nd_path %>%
    read_csv() %>%
    rename(county = "county_name") %>%
    mutate(
        state = "north dakota",
        county = county %>% str_to_lower()
    ) %>%
    left_join(census_data, by = c("state", "county"))

#wa_data <-
#    wa_path %>%
#    read_csv()

#wa_data_2 <-
    #wa_path_2 %>%
    #read_csv()
# Out:
# Multiple files in zip: reading 'ACS_15_5YR_B02001.csv'
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   Id = col_character(),
#   Id2 = col_character(),
#   Geography = col_character()
# )
# See spec(...) for full column specifications.
# Reading layer `tl_2016_us_county' from data source `/Users/michaelspencer/stanford_coding/biglocalpolicing/data/tl_2016_us_county/tl_2016_us_county.shp' using driver `ESRI Shapefile'
# Simple feature collection with 3233 features and 17 fields
# geometry type:  MULTIPOLYGON
# dimension:      XY
# bbox:           xmin: -179.2311 ymin: -14.60181 xmax: 179.8597 ymax: 71.44106
# epsg (SRID):    4269
# proj4string:    +proj=longlat +datum=NAD83 +no_defs
# Multiple files in zip: reading 'nd_statewide_2019_08_13.csv'
# Parsed with column specification:
# cols(
#   raw_row_number = col_character(),
#   date = col_date(format = ""),
#   time = col_time(format = ""),
#   location = col_character(),
#   county_name = col_character(),
#   subject_age = col_double(),
#   subject_race = col_character(),
#   subject_sex = col_character(),
#   type = col_character(),
#   violation = col_character(),
#   outcome = col_character(),
#   raw_Race = col_character()
# )

# %% [markdown]
# ### Shapefiles Exploration

# %%
county_shapefiles_data %>% head()
# Out:
#   STATEFP COUNTYFP COUNTYNS GEOID NAME        county                LSAD
# 1 31      039      00835841 31039 Cuming      Cuming County         06
# 2 53      069      01513275 53069 Wahkiakum   Wahkiakum County      06
# 3 35      011      00933054 35011 De Baca     De Baca County        06
# 4 31      109      00835876 31109 Lancaster   Lancaster County      06
# 5 31      129      00835886 31129 Nuckolls    Nuckolls County       06
# 6 72      085      01804523 72085 Las Piedras Las Piedras Municipio 13
#   CLASSFP MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT ALAND      AWATER   INTPTLAT
# 1 H1      G4020 NA    NA     NA       A        1477895811 10447360 +41.9158651
# 2 H1      G4020 NA    NA     NA       A         680956787 61588406 +46.2946377
# 3 H1      G4020 NA    NA     NA       A        6016761713 29147306 +34.3592729
# 4 H1      G4020 339   30700  NA       A        2169240199 22877180 +40.7835474
# 5 H1      G4020 NA    NA     NA       A        1489645187  1718484 +40.1764918
# 6 H1      G4020 490   41980  NA       A          87748363    32509 +18.1871483
#   INTPTLON     geometry
# 1 -096.7885168 MULTIPOLYGON (((-97.01952 4...
# 2 -123.4244583 MULTIPOLYGON (((-123.4364 4...
# 3 -104.3686961 MULTIPOLYGON (((-104.5674 3...
# 4 -096.6886584 MULTIPOLYGON (((-96.9106 40...
# 5 -098.0468422 MULTIPOLYGON (((-98.27367 4...
# 6 -065.8711890 MULTIPOLYGON (((-65.91048 1...

# %% [markdown]
# ### Census Data Exploration

# %%
## Proportions are shown as percentages (ie 4.9 = 4.9%) to avoid scientific notation

census_data %>%
    filter(geography %>% str_detect("North Dakota"))
# Out:
#    geography                          county               state
# 1  Adams County, North Dakota         adams county         north dakota
# 2  Barnes County, North Dakota        barnes county        north dakota
# 3  Benson County, North Dakota        benson county        north dakota
# 4  Billings County, North Dakota      billings county      north dakota
# 5  Bottineau County, North Dakota     bottineau county     north dakota
# 6  Bowman County, North Dakota        bowman county        north dakota
# 7  Burke County, North Dakota         burke county         north dakota
# 8  Burleigh County, North Dakota      burleigh county      north dakota
# 9  Cass County, North Dakota          cass county          north dakota
# 10 Cavalier County, North Dakota      cavalier county      north dakota
# 11 Dickey County, North Dakota        dickey county        north dakota
# 12 Divide County, North Dakota        divide county        north dakota
# 13 Dunn County, North Dakota          dunn county          north dakota
# 14 Eddy County, North Dakota          eddy county          north dakota
# 15 Emmons County, North Dakota        emmons county        north dakota
# 16 Foster County, North Dakota        foster county        north dakota
# 17 Golden Valley County, North Dakota golden valley county north dakota
# 18 Grand Forks County, North Dakota   grand forks county   north dakota
# 19 Grant County, North Dakota         grant county         north dakota
# 20 Griggs County, North Dakota        griggs county        north dakota
# 21 Hettinger County, North Dakota     hettinger county     north dakota
# 22 Kidder County, North Dakota        kidder county        north dakota
# 23 LaMoure County, North Dakota       lamoure county       north dakota
# 24 Logan County, North Dakota         logan county         north dakota
# 25 McHenry County, North Dakota       mchenry county       north dakota
# 26 McIntosh County, North Dakota      mcintosh county      north dakota
# 27 McKenzie County, North Dakota      mckenzie county      north dakota
# 28 McLean County, North Dakota        mclean county        north dakota
# 29 Mercer County, North Dakota        mercer county        north dakota
# 30 Morton County, North Dakota        morton county        north dakota
# 31 Mountrail County, North Dakota     mountrail county     north dakota
# 32 Nelson County, North Dakota        nelson county        north dakota
# 33 Oliver County, North Dakota        oliver county        north dakota
# 34 Pembina County, North Dakota       pembina county       north dakota
# 35 Pierce County, North Dakota        pierce county        north dakota
# 36 Ramsey County, North Dakota        ramsey county        north dakota
# 37 Ransom County, North Dakota        ransom county        north dakota
# 38 Renville County, North Dakota      renville county      north dakota
# 39 Richland County, North Dakota      richland county      north dakota
# 40 Rolette County, North Dakota       rolette county       north dakota
# 41 Sargent County, North Dakota       sargent county       north dakota
# 42 Sheridan County, North Dakota      sheridan county      north dakota
# 43 Sioux County, North Dakota         sioux county         north dakota
# 44 Slope County, North Dakota         slope county         north dakota
# 45 Stark County, North Dakota         stark county         north dakota
# 46 Steele County, North Dakota        steele county        north dakota
# 47 Stutsman County, North Dakota      stutsman county      north dakota
# 48 Towner County, North Dakota        towner county        north dakota
# 49 Traill County, North Dakota        traill county        north dakota
# 50 Walsh County, North Dakota         walsh county         north dakota
# 51 Ward County, North Dakota          ward county          north dakota
# 52 Wells County, North Dakota         wells county         north dakota
# 53 Williams County, North Dakota      williams county      north dakota
#    total_pop total_na na_pop_prop
# 1    2341       63     2.6911576
# 2   11097      104     0.9371902
# 3    6794     3735    54.9749779
# 4     969        5     0.5159959
# 5    6634      164     2.4721134
# 6    3221       38     1.1797578
# 7    2208       26     1.1775362
# 8   88223     3345     3.7915283
# 9  162500     1898     1.1680000
# 10   3890       45     1.1568123
# 11   5195       42     0.8084697
# 12   2314       36     1.5557476
# 13   4195      458    10.9177592
# 14   2370       99     4.1772152
# 15   3463       11     0.3176437
# 16   3366       28     0.8318479
# 17   1822        8     0.4390779
# 18  68979     1789     2.5935430
# 19   2362       26     1.1007621
# 20   2329       22     0.9446114
# 21   2621       60     2.2892026
# 22   2430        0     0.0000000
# 23   4113        9     0.2188184
# 24   1945        6     0.3084833
# 25   5817       38     0.6532577
# 26   2759       14     0.5074302
# 27   9615     1709    17.7743110
# 28   9451      679     7.1844249
# 29   8633      251     2.9074482
# 30  28985     1053     3.6329136
# 31   9253     2626    28.3799849
# 32   3048       40     1.3123360
# 33   1819       78     4.2880704
# 34   7206      171     2.3730225
# 35   4395       82     1.8657565
# 36  11566     1135     9.8132457
# 37   5453       41     0.7518797
# 38   2562       14     0.5464481
# 39  16317      456     2.7946314
# 40  14498    11210    77.3210098
# 41   3874       22     0.5678885
# 42   1337        6     0.4487659
# 43   4380     3583    81.8036530
# 44    673        0     0.0000000
# 45  28628      272     0.9501188
# 46   1979        0     0.0000000
# 47  21076      325     1.5420383
# 48   2294       49     2.1360070
# 49   8077       88     1.0895134
# 50  11005      201     1.8264425
# 51  67736      905     1.3360694
# 52   4204       10     0.2378687
# 53  29619     1211     4.0885918

# %% [markdown]
# ### North Dakota Analysis

# %%
nd_data %>%
    head()
# Out:
#   raw_row_number date       time     location           county
# 1 91444          2011-05-04 09:58:00 94, 291            barnes county
# 2 138130         2011-12-28 11:41:00 gateway at 55th st grand forks county
# 3 118604         2011-09-16 19:03:00 29, 104            traill county
# 4 74973          2011-01-28 16:46:00 200, 88            dunn county
# 5 57595          2010-10-15 10:46:00 29, 127            grand forks county
# 6 149505         2012-02-21 19:17:00 85, 174            mckenzie county
#   subject_age subject_race subject_sex type
# 1 101         white        male        vehicular
# 2 101         white        male        vehicular
# 3 102         white        male        vehicular
# 4  11         black        male        vehicular
# 5  11         white        male        vehicular
# 6  11         white        male        vehicular
#   violation                               outcome  raw_Race
# 1 390902: Exceeded speed limit            citation White
# 2 391022: Failed to yield at intersection citation White
# 3 390902: Exceeded speed limit            citation White
# 4 390902: Exceeded speed limit            citation African American
# 5 390902: Exceeded speed limit            citation White
# 6 390902: Exceeded speed limit            citation White
#   state        geography                        total_pop total_na na_pop_prop
# 1 north dakota Barnes County, North Dakota      11097      104      0.9371902
# 2 north dakota Grand Forks County, North Dakota 68979     1789      2.5935430
# 3 north dakota Traill County, North Dakota       8077       88      1.0895134
# 4 north dakota Dunn County, North Dakota         4195      458     10.9177592
# 5 north dakota Grand Forks County, North Dakota 68979     1789      2.5935430
# 6 north dakota McKenzie County, North Dakota     9615     1709     17.7743110

# %%
## What is the distribution of stops across each factor (ie county, violation, sex, etc)?

nd_data %>%
    count(raw_Race) %>%
    mutate(prop_of_stops = n/sum(n)) %>%
    arrange(desc(prop_of_stops))

## Native American stops seem to be slightly underrepresented at the state level, 
## based on fact that Native Americans make up ~5% of the total ND population. Will pull in census data later.

nd_data %>%
    count(county) %>%
    mutate(prop_of_stops = n/sum(n)) %>%
    arrange(desc(prop_of_stops))

nd_data %>%
    count(subject_sex) %>%
    mutate(prop_of_stops = n/sum(n)) %>%
    arrange(desc(prop_of_stops))

nd_data %>%
    count(type) %>%
    mutate(prop_of_stops = n/sum(n)) %>%
    arrange(desc(prop_of_stops))

nd_data %>%
    count(violation) %>%
    mutate(prop_of_stops = n/sum(n)) %>%
    arrange(desc(prop_of_stops))

nd_data %>%
    count(outcome) %>%
    mutate(prop_of_stops = n/sum(n)) %>%
    arrange(desc(prop_of_stops))
# Out:
#   raw_Race         n      prop_of_stops
# 1 White            291682 0.8835314359
# 2 Native American   13555 0.0410593338
# 3 African American   9562 0.0289641719
# 4 Hispanic           8713 0.0263924733
# 5 Other              4756 0.0144063587
# 6 Asian              1691 0.0051221935
# 7 NA                  173 0.0005240328
#    county               n     prop_of_stops
# 1  cass county          40211 1.218028e-01
# 2  ward county          32371 9.805472e-02
# 3  grand forks county   31219 9.456520e-02
# 4  williams county      20328 6.157537e-02
# 5  ramsey county        17096 5.178535e-02
# 6  stark county         16373 4.959531e-02
# 7  morton county        14808 4.485479e-02
# 8  stutsman county      14450 4.377037e-02
# 9  burleigh county      14176 4.294040e-02
# 10 mckenzie county      10820 3.277477e-02
# 11 mclean county         9955 3.015460e-02
# 12 barnes county         8376 2.537167e-02
# 13 richland county       8049 2.438116e-02
# 14 walsh county          7726 2.340276e-02
# 15 traill county         6628 2.007682e-02
# 16 mountrail county      5150 1.559982e-02
# 17 dunn county           4773 1.445785e-02
# 18 bottineau county      4619 1.399137e-02
# 19 rolette county        4201 1.272521e-02
# 20 nelson county         4149 1.256770e-02
# 21 pembina county        3904 1.182557e-02
# 22 mchenry county        3481 1.054427e-02
# 23 wells county          3224 9.765791e-03
# 24 billings county       2733 8.278507e-03
# 25 bowman county         2705 8.193692e-03
# 26 lamoure county        2683 8.127052e-03
# 27 sargent county        2585 7.830201e-03
# 28 benson county         2545 7.709038e-03
# 29 kidder county         2454 7.433390e-03
# 30 pierce county         2421 7.333430e-03
# 31 ransom county         2385 7.224383e-03
# 32 slope county          2274 6.888154e-03
# 33 adams county          2191 6.636739e-03
# 34 foster county         1800 5.452365e-03
# 35 mercer county         1694 5.131281e-03
# 36 cavalier county       1660 5.028292e-03
# 37 divide county         1643 4.976797e-03
# 38 dickey county         1370 4.149855e-03
# 39 oliver county         1308 3.962052e-03
# 40 towner county         1243 3.765161e-03
# 41 golden valley county  1041 3.153284e-03
# 42 emmons county         1036 3.138139e-03
# 43 renville county        967 2.929131e-03
# 44 hettinger county       930 2.817055e-03
# 45 grant county           850 2.574728e-03
# 46 steele county          828 2.508088e-03
# 47 burke county           747 2.262731e-03
# 48 griggs county          614 1.859862e-03
# 49 logan county           418 1.266160e-03
# 50 eddy county            368 1.114706e-03
# 51 mcintosh county        300 9.087274e-04
# 52 sheridan county        231 6.997201e-04
# 53 sioux county            21 6.361092e-05
#   subject_sex n      prop_of_stops
# 1 male        242904 0.7357784159
# 2 female       87137 0.2639459368
# 3 NA              91 0.0002756473
#   type      n      prop_of_stops
# 1 vehicular 327573 0.992248555
# 2 NA          2559 0.007751445
#      violation
# 1    390902: Exceeded speed limit
# 2    3921414: No seat belt
# 3    390902: Exceeded speed limit|3921414: No seat belt
# 4    3904371: Failed to register motor vehicle  upon gainful employment
# 5    391044: Disregarded stop sign
# 6    3921394: Vehicle having tinted windshield
# 7    3921463: Commercial Motor Vehicle Violations
# 8    390801: Drove or in actual physical control of a motor vehicle while under the influence of alcohol or drugs and/or with AC of .08 or greater and/or
# 9    3909011: Care required
# 10   390411: Failed to display number plates/tabs
# 11   390902: Exceeded speed limit|3904371: Failed to register motor vehicle  upon gainful employment
# 12   390642: Drove while license suspended(4 or more offenses)
# 13   3909022: Exceeded speed limit in construction zone (Workers Present)
# 14   3921414: No seat belt|390902: Exceeded speed limit
# 15   3921412: Person under 18 years of age not properly restrained
# 16   391044: Disregarded stop sign|3921414: No seat belt
# 17   391005: Drove thru red light/Fail to yield to pedestrian
# 18   390902: Exceeded speed limit|390642: Drove while license suspended(4 or more offenses)
# 19   390601: Drove without\\expired operators license
# 20   391208: Operating without Size & Weight permit
# 21   3910181: Following too close
# 22   390902: Exceeded speed limit|3921394: Vehicle having tinted windshield
# 23   390820: Driving without Liability Insurance
# 24   3904371: Failed to register motor vehicle  upon gainful employment|3921414: No seat belt
# 25   390818: Open container of alcoholic beverage
# 26   50108: Possession/consumption of alcohol by a person under the age of 21
# 27   3912053: Overweight Limitations - Other than Interstate
# 28   390902: Exceeded speed limit|390601: Drove without\\expired operators license
# 29   3921211: Failed to dim headlamps for approaching veh
# 30   391015: Overtook when prohibited
# ⋮    ⋮
# 6183 50108: Possession/consumption of alcohol by a person under the age of 21|6210402: Carrying a concealed weapon|1903123: Possession of a controlled substance with intent to manufacture or deliver-sch.I,II,III or analog|1903403: Unlawful possession of drug paraphernalia
# 6184 62102011: Felon in Possession of a Firearm
# 6185 6210206: Discharging Firearm in city limits
# 6186 6210210: Carrying a loaded firearm in a vehicle|1903123: Possession of a controlled substance with intent to manufacture or deliver-sch.I,II,III or analog|390902: Exceeded speed limit
# 6187 6210210: Carrying a loaded firearm in a vehicle|1903403: Unlawful possession of drug paraphernalia
# 6188 6210210: Carrying a loaded firearm in a vehicle|3904371: Failed to register motor vehicle  upon gainful employment
# 6189 6210210: Carrying a loaded firearm in a vehicle|390902: Exceeded speed limit
# 6190 6210210: Carrying a loaded firearm in a vehicle|390902: Exceeded speed limit|3921414: No seat belt|390642: Drove while license suspended(4 or more offenses)
# 6191 6210210: Carrying a loaded firearm in a vehicle|392144: Hazardous Material violations|3921412: Person under 18 years of age not properly restrained
# 6192 6210210: Carrying a loaded firearm in a vehicle|6210402: Carrying a concealed weapon|390801: Drove or in actual physical control of a motor vehicle while under the influence of alcohol or drugs and/or with AC of .08 or greater and/or|19031236: Possession of a Controlled Substance
# 6193 6210210: Carrying a loaded firearm in a vehicle|6210402: Carrying a concealed weapon|390902: Exceeded speed limit
# 6194 6210210: Carrying a loaded firearm in a vehicle|6210402: Carrying a concealed weapon|391044: Disregarded stop sign
# 6195 6210210: Carrying a loaded firearm in a vehicle|6210402: Carrying a concealed weapon|3921414: No seat belt
# 6196 6210301: Carrying a handgun other than permitted by law|1903403: Unlawful possession of drug paraphernalia|1903123: Possession of a controlled substance with intent to manufacture or deliver-sch.I,II,III or analog|390801: Drove or in actual physical control of a motor vehicle while under the influence of alcohol or drugs and/or with AC of .08 or greater and/or
# 6197 6210301: Carrying a handgun other than permitted by law|1903403: Unlawful possession of drug paraphernalia|390801: Drove or in actual physical control of a motor vehicle while under the influence of alcohol or drugs and/or with AC of .08 or greater and/or
# 6198 6210301: Carrying a handgun other than permitted by law|6210402: Carrying a concealed weapon
# 6199 6210402: Carrying a concealed weapon|1210803: Hindering/Interfering with an officer|390801: Drove or in actual physical control of a motor vehicle while under the influence of alcohol or drugs and/or with AC of .08 or greater and/or
# 6200 6210402: Carrying a concealed weapon|1211704: Terrorizing
# 6201 6210402: Carrying a concealed weapon|12131032: Possession of tobacco products by a minor|12131032: Possession of tobacco products by a minor
# 6202 6210402: Carrying a concealed weapon|1903403: Unlawful possession of drug paraphernalia|19031236: Possession of a Controlled Substance
# 6203 6210402: Carrying a concealed weapon|1903403: Unlawful possession of drug paraphernalia|1903403: Unlawful possession of drug paraphernalia|6210210: Carrying a loaded firearm in a vehicle|19031231: Aggravated drug offense designated as a class A felony under 19-03.1-23|62102011: Felon in Possession of a Firearm
# 6204 6210402: Carrying a concealed weapon|3904371: Failed to register motor vehicle  upon gainful employment
# 6205 6210402: Carrying a concealed weapon|390820: Driving without Liability Insurance
# 6206 6210402: Carrying a concealed weapon|390820: Driving without Liability Insurance|390642: Drove while license suspended(4 or more offenses)|390517: Failure to transfer title of vehicle
# 6207 6210402: Carrying a concealed weapon|390820: Driving without Liability Insurance|390642: Drove while license suspended(4 or more offenses)|390902: Exceeded speed limit
# 6208 6210402: Carrying a concealed weapon|391059: Depositing rubbish on roadway
# 6209 6210402: Carrying a concealed weapon|3921414: No seat belt|390820: Driving without Liability Insurance|391044: Disregarded stop sign
# 6210 6210402: Carrying a concealed weapon|6210210: Carrying a loaded firearm in a vehicle|390902: Exceeded speed limit
# 6211 6210402: Carrying a concealed weapon|6210210: Carrying a loaded firearm in a vehicle|3921212: Failed to dim headlamps when following veh
# 6212 6210402: Carrying a concealed weapon|6210402: Carrying a concealed weapon|6210210: Carrying a loaded firearm in a vehicle|390902: Exceeded speed limit
#      n      prop_of_stops
# 1    171436 0.519295312
# 2     22670 0.068669502
# 3     12436 0.037669781
# 4     11686 0.035397962
# 5     11486 0.034792144
# 6      7330 0.022203240
# 7      4612 0.013970170
# 8      4576 0.013861122
# 9      3862 0.011698351
# 10     3775 0.011434820
# 11     2997 0.009078187
# 12     2750 0.008330001
# 13     2598 0.007869579
# 14     1992 0.006033950
# 15     1810 0.005482655
# 16     1638 0.004961652
# 17     1588 0.004810197
# 18     1313 0.003977197
# 19     1304 0.003949935
# 20     1276 0.003865121
# 21     1220 0.003695492
# 22     1205 0.003650055
# 23     1203 0.003643997
# 24     1195 0.003619764
# 25     1192 0.003610677
# 26     1180 0.003574328
# 27     1008 0.003053324
# 28      945 0.002862491
# 29      889 0.002692862
# 30      880 0.002665600
# ⋮    ⋮      ⋮
# 6183 1      3.029091e-06
# 6184 1      3.029091e-06
# 6185 1      3.029091e-06
# 6186 1      3.029091e-06
# 6187 1      3.029091e-06
# 6188 1      3.029091e-06
# 6189 1      3.029091e-06
# 6190 1      3.029091e-06
# 6191 1      3.029091e-06
# 6192 1      3.029091e-06
# 6193 1      3.029091e-06
# 6194 1      3.029091e-06
# 6195 1      3.029091e-06
# 6196 1      3.029091e-06
# 6197 1      3.029091e-06
# 6198 1      3.029091e-06
# 6199 1      3.029091e-06
# 6200 1      3.029091e-06
# 6201 1      3.029091e-06
# 6202 1      3.029091e-06
# 6203 1      3.029091e-06
# 6204 1      3.029091e-06
# 6205 1      3.029091e-06
# 6206 1      3.029091e-06
# 6207 1      3.029091e-06
# 6208 1      3.029091e-06
# 6209 1      3.029091e-06
# 6210 1      3.029091e-06
# 6211 1      3.029091e-06
# 6212 1      3.029091e-06
#   outcome  n      prop_of_stops
# 1 citation 330132 1

# %%
nd_na_stops_data <-
    nd_data %>%
    filter(raw_Race == "Native American")

# %%
## What is the distribution of Native American stops across relevant factors (ie county, sex, type, violation, etc)

nd_na_stops_data %>%
    count(county) %>%
    mutate(prop_of_stops = n/sum(n)) %>%
    arrange(desc(prop_of_stops))

nd_na_stops_data %>%
    count(subject_sex) %>%
    mutate(prop_of_stops = n/sum(n)) %>%
    arrange(desc(prop_of_stops))

nd_na_stops_data %>%
    count(type) %>%
    mutate(prop_of_stops = n/sum(n)) %>%
    arrange(desc(prop_of_stops))

nd_na_stops_data %>%
    count(violation) %>%
    mutate(prop_of_stops = n/sum(n)) %>%
    arrange(desc(prop_of_stops))

nd_na_stops_data %>%
    count(outcome) %>%
    mutate(prop_of_stops = n/sum(n)) %>%
    arrange(desc(prop_of_stops))
# Out:
#    county               n    prop_of_stops
# 1  rolette county       2733 0.2016230173
# 2  ramsey county        2305 0.1700479528
# 3  ward county          1375 0.1014385835
# 4  morton county        1127 0.0831427518
# 5  mclean county         755 0.0556990041
# 6  grand forks county    687 0.0506824050
# 7  burleigh county       582 0.0429361859
# 8  bottineau county      488 0.0360014755
# 9  cass county           364 0.0268535596
# 10 pierce county         361 0.0266322390
# 11 towner county         286 0.0210992254
# 12 nelson county         261 0.0192548875
# 13 mchenry county        238 0.0175580966
# 14 williams county       238 0.0175580966
# 15 stutsman county       174 0.0128365917
# 16 dunn county           170 0.0125414976
# 17 benson county         166 0.0122464035
# 18 stark county          164 0.0120988565
# 19 richland county       162 0.0119513095
# 20 mckenzie county       132 0.0097381040
# 21 mountrail county      103 0.0075986721
# 22 barnes county          70 0.0051641461
# 23 traill county          69 0.0050903726
# 24 cavalier county        39 0.0028771671
# 25 kidder county          39 0.0028771671
# 26 walsh county           39 0.0028771671
# 27 wells county           39 0.0028771671
# 28 pembina county         33 0.0024345260
# 29 foster county          30 0.0022132055
# 30 slope county           28 0.0020656584
# 31 adams county           26 0.0019181114
# 32 billings county        26 0.0019181114
# 33 oliver county          24 0.0017705644
# 34 mercer county          23 0.0016967909
# 35 eddy county            22 0.0016230173
# 36 sargent county         22 0.0016230173
# 37 bowman county          20 0.0014754703
# 38 lamoure county         20 0.0014754703
# 39 dickey county          15 0.0011066027
# 40 renville county        15 0.0011066027
# 41 hettinger county       14 0.0010328292
# 42 emmons county          11 0.0008115087
# 43 golden valley county   10 0.0007377352
# 44 burke county            9 0.0006639616
# 45 grant county            9 0.0006639616
# 46 divide county           7 0.0005164146
# 47 sheridan county         7 0.0005164146
# 48 ransom county           6 0.0004426411
# 49 griggs county           4 0.0002950941
# 50 mcintosh county         3 0.0002213205
# 51 steele county           3 0.0002213205
# 52 sioux county            2 0.0001475470
#   subject_sex n    prop_of_stops
# 1 male        7997 0.5899668
# 2 female      5558 0.4100332
#   type      n     prop_of_stops
# 1 vehicular 13297 0.98096643
# 2 NA          258 0.01903357
#      violation
# 1    390902: Exceeded speed limit
# 2    3921414: No seat belt
# 3    3904371: Failed to register motor vehicle  upon gainful employment
# 4    390642: Drove while license suspended(4 or more offenses)
# 5    390902: Exceeded speed limit|3921414: No seat belt
# 6    3921394: Vehicle having tinted windshield
# 7    390601: Drove without\\expired operators license
# 8    390820: Driving without Liability Insurance
# 9    390642: Drove while license suspended(4 or more offenses)|390820: Driving without Liability Insurance
# 10   391044: Disregarded stop sign
# 11   390801: Drove or in actual physical control of a motor vehicle while under the influence of alcohol or drugs and/or with AC of .08 or greater and/or
# 12   390818: Open container of alcoholic beverage
# 13   3921412: Person under 18 years of age not properly restrained
# 14   390902: Exceeded speed limit|390642: Drove while license suspended(4 or more offenses)
# 15   390902: Exceeded speed limit|390601: Drove without\\expired operators license
# 16   390902: Exceeded speed limit|3921394: Vehicle having tinted windshield
# 17   390902: Exceeded speed limit|3904371: Failed to register motor vehicle  upon gainful employment
# 18   390411: Failed to display number plates/tabs
# 19   390902: Exceeded speed limit|3921412: Person under 18 years of age not properly restrained
# 20   50108: Possession/consumption of alcohol by a person under the age of 21
# 21   390801: Drove or in actual physical control of a motor vehicle while under the influence of alcohol or drugs and/or with AC of .08 or greater and/or|390642: Drove while license suspended(4 or more offenses)
# 22   390601: Drove without\\expired operators license|390820: Driving without Liability Insurance
# 23   3909011: Care required
# 24   3921414: No seat belt|390902: Exceeded speed limit
# 25   3921211: Failed to dim headlamps for approaching veh
# 26   390902: Exceeded speed limit|390820: Driving without Liability Insurance
# 27   3904371: Failed to register motor vehicle  upon gainful employment|3921414: No seat belt
# 28   391005: Drove thru red light/Fail to yield to pedestrian
# 29   390642: Drove while license suspended(4 or more offenses)|390902: Exceeded speed limit
# 30   3909022: Exceeded speed limit in construction zone (Workers Present)
# ⋮    ⋮
# 1083 3921442: Improper drawbar or connections between vehicles
# 1084 3921451: Modification of motor vehicle|3921394: Vehicle having tinted windshield
# 1085 3921461: Operating an unsafe vehicle|392137: Defective muffler or no muffler(not operated)
# 1086 3921462: Operating an unsafe vehicle
# 1087 3921462: Operating an unsafe vehicle|390644: Permitting unauthorized minor to drive
# 1088 3921463: Commercial Motor Vehicle Violations|3904371: Failed to register motor vehicle  upon gainful employment
# 1089 3921463: Commercial Motor Vehicle Violations|390614: Drove vehicle other than permitted by license
# 1090 3921463: Commercial Motor Vehicle Violations|390902: Exceeded speed limit
# 1091 3921463: Commercial Motor Vehicle Violations|391208: Operating without Size & Weight permit
# 1092 3921463: Commercial Motor Vehicle Violations|3921412: Person under 18 years of age not properly restrained
# 1093 3921463: Commercial Motor Vehicle Violations|3921414: No seat belt
# 1094 3921463: Commercial Motor Vehicle Violations|3921463: Commercial Motor Vehicle Violations|390642: Drove while license suspended(4 or more offenses)
# 1095 392902: Failed to register OHV|39290901: Operating OHV - Equipment Violation|3929091: Operated on shoulder of street, highway, or interstate when prohibited -OHV
# 1096 392902: Failed to register OHV|3929099: No helmet worn - operator or passenger under 18 years - OHV
# 1097 3929092a: Crossed roadway other than 90 degree angle-OHV
# 1098 3929099: No helmet worn - operator or passenger under 18 years - OHV|392910: Operation of ATV under 16 (without certificate)
# 1099 501051: Intoxicated person|1213101: Disorderly Conduct
# 1100 501051: Intoxicated person|390818: Open container of alcoholic beverage
# 1101 50108: Possession/consumption of alcohol by a person under the age of 21|1210803: Hindering/Interfering with an officer|1211103: False information to a police officer
# 1102 50108: Possession/consumption of alcohol by a person under the age of 21|1211103: False information to a police officer
# 1103 50108: Possession/consumption of alcohol by a person under the age of 21|1211701: Simple Assault on a peace or corrections officer|1903123: Possession of a controlled substance with intent to manufacture or deliver-sch.I,II,III or analog
# 1104 50108: Possession/consumption of alcohol by a person under the age of 21|1903123: Possession of a controlled substance with intent to manufacture or deliver-sch.I,II,III or analog
# 1105 50108: Possession/consumption of alcohol by a person under the age of 21|1903123: Possession of a controlled substance with intent to manufacture or deliver-sch.I,II,III or analog|1903403: Unlawful possession of drug paraphernalia|391059: Depositing rubbish on roadway
# 1106 50108: Possession/consumption of alcohol by a person under the age of 21|1903123: Possession of a controlled substance with intent to manufacture or deliver-sch.I,II,III or analog|6210402: Carrying a concealed weapon|50108: Possession/consumption of alcohol by a person under the age of 21|50108: Possession/consumption of alcohol by a person under the age of 21
# 1107 50108: Possession/consumption of alcohol by a person under the age of 21|19031231: Aggravated drug offense designated as a class A felony under 19-03.1-23
# 1108 50108: Possession/consumption of alcohol by a person under the age of 21|390601: Drove without\\expired operators license
# 1109 50108: Possession/consumption of alcohol by a person under the age of 21|390902: Exceeded speed limit
# 1110 50108: Possession/consumption of alcohol by a person under the age of 21|3921394: Vehicle having tinted windshield
# 1111 50109: Delivering alcohol to minor|390818: Open container of alcoholic beverage
# 1112 6210301: Carrying a handgun other than permitted by law|1903403: Unlawful possession of drug paraphernalia|390801: Drove or in actual physical control of a motor vehicle while under the influence of alcohol or drugs and/or with AC of .08 or greater and/or
#      n    prop_of_stops
# 1    5350 0.394688307
# 2     804 0.059313906
# 3     519 0.038288454
# 4     454 0.033493176
# 5     452 0.033345629
# 6     450 0.033198082
# 7     235 0.017336776
# 8     227 0.016746588
# 9     208 0.015344891
# 10    200 0.014754703
# 11    195 0.014385835
# 12    194 0.014312062
# 13    194 0.014312062
# 14    151 0.011139801
# 15    110 0.008115087
# 16     88 0.006492069
# 17     86 0.006344522
# 18     85 0.006270749
# 19     75 0.005533014
# 20     75 0.005533014
# 21     70 0.005164146
# 22     67 0.004942826
# 23     67 0.004942826
# 24     65 0.004795278
# 25     62 0.004573958
# 26     56 0.004131317
# 27     52 0.003836223
# 28     49 0.003614902
# 29     48 0.003541129
# 30     46 0.003393582
# ⋮    ⋮    ⋮
# 1083 1    7.377352e-05
# 1084 1    7.377352e-05
# 1085 1    7.377352e-05
# 1086 1    7.377352e-05
# 1087 1    7.377352e-05
# 1088 1    7.377352e-05
# 1089 1    7.377352e-05
# 1090 1    7.377352e-05
# 1091 1    7.377352e-05
# 1092 1    7.377352e-05
# 1093 1    7.377352e-05
# 1094 1    7.377352e-05
# 1095 1    7.377352e-05
# 1096 1    7.377352e-05
# 1097 1    7.377352e-05
# 1098 1    7.377352e-05
# 1099 1    7.377352e-05
# 1100 1    7.377352e-05
# 1101 1    7.377352e-05
# 1102 1    7.377352e-05
# 1103 1    7.377352e-05
# 1104 1    7.377352e-05
# 1105 1    7.377352e-05
# 1106 1    7.377352e-05
# 1107 1    7.377352e-05
# 1108 1    7.377352e-05
# 1109 1    7.377352e-05
# 1110 1    7.377352e-05
# 1111 1    7.377352e-05
# 1112 1    7.377352e-05
#   outcome  n     prop_of_stops
# 1 citation 13555 1

# %% [markdown]
# #### Glancing at disproportionate stops with census data

# %%
nd_data %>% head()
# Out:
#   raw_row_number date       time     location           county
# 1 91444          2011-05-04 09:58:00 94, 291            barnes county
# 2 138130         2011-12-28 11:41:00 gateway at 55th st grand forks county
# 3 118604         2011-09-16 19:03:00 29, 104            traill county
# 4 74973          2011-01-28 16:46:00 200, 88            dunn county
# 5 57595          2010-10-15 10:46:00 29, 127            grand forks county
# 6 149505         2012-02-21 19:17:00 85, 174            mckenzie county
#   subject_age subject_race subject_sex type
# 1 101         white        male        vehicular
# 2 101         white        male        vehicular
# 3 102         white        male        vehicular
# 4  11         black        male        vehicular
# 5  11         white        male        vehicular
# 6  11         white        male        vehicular
#   violation                               outcome  raw_Race
# 1 390902: Exceeded speed limit            citation White
# 2 391022: Failed to yield at intersection citation White
# 3 390902: Exceeded speed limit            citation White
# 4 390902: Exceeded speed limit            citation African American
# 5 390902: Exceeded speed limit            citation White
# 6 390902: Exceeded speed limit            citation White
#   state        geography                        total_pop total_na na_pop_prop
# 1 north dakota Barnes County, North Dakota      11097      104      0.9371902
# 2 north dakota Grand Forks County, North Dakota 68979     1789      2.5935430
# 3 north dakota Traill County, North Dakota       8077       88      1.0895134
# 4 north dakota Dunn County, North Dakota         4195      458     10.9177592
# 5 north dakota Grand Forks County, North Dakota 68979     1789      2.5935430
# 6 north dakota McKenzie County, North Dakota     9615     1709     17.7743110

# %%
## Sorted by proportion of NA stops - NA proportion in the population (ie the disparity)

nd_data %>%
    group_by(geography, na_pop_prop, raw_Race) %>%
    summarize(
        total_num_stops = n()
    ) %>%
    mutate(prop_of_stops = (total_num_stops/sum(total_num_stops)) * 100) %>%
    filter(raw_Race == "Native American") %>%
    mutate(disprop_stops = prop_of_stops - na_pop_prop) %>%
    arrange(desc(disprop_stops))
# Out:
#    geography                          na_pop_prop raw_Race
# 1  Towner County, North Dakota         2.1360070  Native American
# 2  Pierce County, North Dakota         1.8657565  Native American
# 3  Bottineau County, North Dakota      2.4721134  Native American
# 4  McHenry County, North Dakota        0.6532577  Native American
# 5  Nelson County, North Dakota         1.3123360  Native American
# 6  Morton County, North Dakota         3.6329136  Native American
# 7  Ramsey County, North Dakota         9.8132457  Native American
# 8  Ward County, North Dakota           1.3360694  Native American
# 9  Sheridan County, North Dakota       0.4487659  Native American
# 10 Eddy County, North Dakota           4.1772152  Native American
# 11 Kidder County, North Dakota         0.0000000  Native American
# 12 Slope County, North Dakota          0.0000000  Native American
# 13 Cavalier County, North Dakota       1.1568123  Native American
# 14 Renville County, North Dakota       0.5464481  Native American
# 15 Wells County, North Dakota          0.2378687  Native American
# 16 Foster County, North Dakota         0.8318479  Native American
# 17 Emmons County, North Dakota         0.3176437  Native American
# 18 LaMoure County, North Dakota        0.2188184  Native American
# 19 Golden Valley County, North Dakota  0.4390779  Native American
# 20 McIntosh County, North Dakota       0.5074302  Native American
# 21 Billings County, North Dakota       0.5159959  Native American
# 22 McLean County, North Dakota         7.1844249  Native American
# 23 Steele County, North Dakota         0.0000000  Native American
# 24 Burleigh County, North Dakota       3.7915283  Native American
# 25 Dickey County, North Dakota         0.8084697  Native American
# 26 Sargent County, North Dakota        0.5678885  Native American
# 27 Stark County, North Dakota          0.9501188  Native American
# 28 Burke County, North Dakota          1.1775362  Native American
# 29 Grant County, North Dakota          1.1007621  Native American
# 30 Traill County, North Dakota         1.0895134  Native American
# 31 Barnes County, North Dakota         0.9371902  Native American
# 32 Cass County, North Dakota           1.1680000  Native American
# 33 Griggs County, North Dakota         0.9446114  Native American
# 34 Stutsman County, North Dakota       1.5420383  Native American
# 35 Grand Forks County, North Dakota    2.5935430  Native American
# 36 Bowman County, North Dakota         1.1797578  Native American
# 37 Ransom County, North Dakota         0.7518797  Native American
# 38 Richland County, North Dakota       2.7946314  Native American
# 39 Hettinger County, North Dakota      2.2892026  Native American
# 40 Divide County, North Dakota         1.5557476  Native American
# 41 Walsh County, North Dakota          1.8264425  Native American
# 42 Adams County, North Dakota          2.6911576  Native American
# 43 Pembina County, North Dakota        2.3730225  Native American
# 44 Mercer County, North Dakota         2.9074482  Native American
# 45 Oliver County, North Dakota         4.2880704  Native American
# 46 Williams County, North Dakota       4.0885918  Native American
# 47 Dunn County, North Dakota          10.9177592  Native American
# 48 Rolette County, North Dakota       77.3210098  Native American
# 49 McKenzie County, North Dakota      17.7743110  Native American
# 50 Mountrail County, North Dakota     28.3799849  Native American
# 51 Benson County, North Dakota        54.9749779  Native American
# 52 Sioux County, North Dakota         81.8036530  Native American
#    total_num_stops prop_of_stops disprop_stops
# 1   286            23.0088496     20.87284258
# 2   361            14.9111937     13.04543718
# 3   488            10.5650574      8.09294402
# 4   238             6.8371158      6.18385808
# 5   261             6.2906725      4.97833649
# 6  1127             7.6107509      3.97783737
# 7  2305            13.4826860      3.66944029
# 8  1375             4.2476291      2.91155960
# 9     7             3.0303030      2.58153714
# 10   22             5.9782609      1.80104568
# 11   39             1.5892421      1.58924205
# 12   28             1.2313105      1.23131047
# 13   39             2.3493976      1.19258525
# 14   15             1.5511892      1.00474116
# 15   39             1.2096774      0.97180872
# 16   30             1.6666667      0.83481878
# 17   11             1.0617761      0.74413240
# 18   20             0.7454342      0.52661583
# 19   10             0.9606148      0.52153686
# 20    3             1.0000000      0.49256977
# 21   26             0.9513355      0.43533966
# 22  755             7.5841286      0.39970365
# 23    3             0.3623188      0.36231884
# 24  582             4.1055305      0.31400219
# 25   15             1.0948905      0.28642083
# 26   22             0.8510638      0.28317534
# 27  164             1.0016491      0.05153029
# 28    9             1.2048193      0.02728305
# 29    9             1.0588235     -0.04193854
# 30   69             1.0410380     -0.04847541
# 31   70             0.8357211     -0.10146912
# 32  364             0.9052249     -0.26277506
# 33    4             0.6514658     -0.29314562
# 34  174             1.2041522     -0.33788609
# 35  687             2.2005830     -0.39295998
# 36   20             0.7393715     -0.44038630
# 37    6             0.2515723     -0.50030737
# 38  162             2.0126724     -0.78195898
# 39   14             1.5053763     -0.78382625
# 40    7             0.4260499     -1.12969771
# 41   39             0.5047890     -1.32165350
# 42   26             1.1866728     -1.50448487
# 43   33             0.8452869     -1.52773560
# 44   23             1.3577332     -1.54971499
# 45   24             1.8348624     -2.45320798
# 46  238             1.1707989     -2.91779288
# 47  170             3.5617012     -7.35605800
# 48 2733            65.0559391    -12.26507073
# 49  132             1.2199630    -16.55434794
# 50  103             2.0000000    -26.37998487
# 51  166             6.5225933    -48.45238460
# 52    2             9.5238095    -72.27984344

# %%
## Sorted by NA % of the Population

nd_data %>%
    group_by(geography, na_pop_prop, raw_Race) %>%
    summarize(
        total_num_stops = n()
    ) %>%
    mutate(prop_of_stops = (total_num_stops/sum(total_num_stops)) * 100) %>%
    filter(raw_Race == "Native American") %>%
    mutate(disprop_stops = prop_of_stops - na_pop_prop) %>%
    arrange(desc(na_pop_prop))
# Out:
#    geography                          na_pop_prop raw_Race
# 1  Sioux County, North Dakota         81.8036530  Native American
# 2  Rolette County, North Dakota       77.3210098  Native American
# 3  Benson County, North Dakota        54.9749779  Native American
# 4  Mountrail County, North Dakota     28.3799849  Native American
# 5  McKenzie County, North Dakota      17.7743110  Native American
# 6  Dunn County, North Dakota          10.9177592  Native American
# 7  Ramsey County, North Dakota         9.8132457  Native American
# 8  McLean County, North Dakota         7.1844249  Native American
# 9  Oliver County, North Dakota         4.2880704  Native American
# 10 Eddy County, North Dakota           4.1772152  Native American
# 11 Williams County, North Dakota       4.0885918  Native American
# 12 Burleigh County, North Dakota       3.7915283  Native American
# 13 Morton County, North Dakota         3.6329136  Native American
# 14 Mercer County, North Dakota         2.9074482  Native American
# 15 Richland County, North Dakota       2.7946314  Native American
# 16 Adams County, North Dakota          2.6911576  Native American
# 17 Grand Forks County, North Dakota    2.5935430  Native American
# 18 Bottineau County, North Dakota      2.4721134  Native American
# 19 Pembina County, North Dakota        2.3730225  Native American
# 20 Hettinger County, North Dakota      2.2892026  Native American
# 21 Towner County, North Dakota         2.1360070  Native American
# 22 Pierce County, North Dakota         1.8657565  Native American
# 23 Walsh County, North Dakota          1.8264425  Native American
# 24 Divide County, North Dakota         1.5557476  Native American
# 25 Stutsman County, North Dakota       1.5420383  Native American
# 26 Ward County, North Dakota           1.3360694  Native American
# 27 Nelson County, North Dakota         1.3123360  Native American
# 28 Bowman County, North Dakota         1.1797578  Native American
# 29 Burke County, North Dakota          1.1775362  Native American
# 30 Cass County, North Dakota           1.1680000  Native American
# 31 Cavalier County, North Dakota       1.1568123  Native American
# 32 Grant County, North Dakota          1.1007621  Native American
# 33 Traill County, North Dakota         1.0895134  Native American
# 34 Stark County, North Dakota          0.9501188  Native American
# 35 Griggs County, North Dakota         0.9446114  Native American
# 36 Barnes County, North Dakota         0.9371902  Native American
# 37 Foster County, North Dakota         0.8318479  Native American
# 38 Dickey County, North Dakota         0.8084697  Native American
# 39 Ransom County, North Dakota         0.7518797  Native American
# 40 McHenry County, North Dakota        0.6532577  Native American
# 41 Sargent County, North Dakota        0.5678885  Native American
# 42 Renville County, North Dakota       0.5464481  Native American
# 43 Billings County, North Dakota       0.5159959  Native American
# 44 McIntosh County, North Dakota       0.5074302  Native American
# 45 Sheridan County, North Dakota       0.4487659  Native American
# 46 Golden Valley County, North Dakota  0.4390779  Native American
# 47 Emmons County, North Dakota         0.3176437  Native American
# 48 Wells County, North Dakota          0.2378687  Native American
# 49 LaMoure County, North Dakota        0.2188184  Native American
# 50 Kidder County, North Dakota         0.0000000  Native American
# 51 Slope County, North Dakota          0.0000000  Native American
# 52 Steele County, North Dakota         0.0000000  Native American
#    total_num_stops prop_of_stops disprop_stops
# 1     2             9.5238095    -72.27984344
# 2  2733            65.0559391    -12.26507073
# 3   166             6.5225933    -48.45238460
# 4   103             2.0000000    -26.37998487
# 5   132             1.2199630    -16.55434794
# 6   170             3.5617012     -7.35605800
# 7  2305            13.4826860      3.66944029
# 8   755             7.5841286      0.39970365
# 9    24             1.8348624     -2.45320798
# 10   22             5.9782609      1.80104568
# 11  238             1.1707989     -2.91779288
# 12  582             4.1055305      0.31400219
# 13 1127             7.6107509      3.97783737
# 14   23             1.3577332     -1.54971499
# 15  162             2.0126724     -0.78195898
# 16   26             1.1866728     -1.50448487
# 17  687             2.2005830     -0.39295998
# 18  488            10.5650574      8.09294402
# 19   33             0.8452869     -1.52773560
# 20   14             1.5053763     -0.78382625
# 21  286            23.0088496     20.87284258
# 22  361            14.9111937     13.04543718
# 23   39             0.5047890     -1.32165350
# 24    7             0.4260499     -1.12969771
# 25  174             1.2041522     -0.33788609
# 26 1375             4.2476291      2.91155960
# 27  261             6.2906725      4.97833649
# 28   20             0.7393715     -0.44038630
# 29    9             1.2048193      0.02728305
# 30  364             0.9052249     -0.26277506
# 31   39             2.3493976      1.19258525
# 32    9             1.0588235     -0.04193854
# 33   69             1.0410380     -0.04847541
# 34  164             1.0016491      0.05153029
# 35    4             0.6514658     -0.29314562
# 36   70             0.8357211     -0.10146912
# 37   30             1.6666667      0.83481878
# 38   15             1.0948905      0.28642083
# 39    6             0.2515723     -0.50030737
# 40  238             6.8371158      6.18385808
# 41   22             0.8510638      0.28317534
# 42   15             1.5511892      1.00474116
# 43   26             0.9513355      0.43533966
# 44    3             1.0000000      0.49256977
# 45    7             3.0303030      2.58153714
# 46   10             0.9606148      0.52153686
# 47   11             1.0617761      0.74413240
# 48   39             1.2096774      0.97180872
# 49   20             0.7454342      0.52661583
# 50   39             1.5892421      1.58924205
# 51   28             1.2313105      1.23131047
# 52    3             0.3623188      0.36231884

# %%
nd_data %>%
    group_by(geography, na_pop_prop, raw_Race) %>%
    summarize(
        total_num_stops = n()
    ) %>%
    mutate(prop_of_stops = (total_num_stops/sum(total_num_stops)) * 100) %>%
    filter(raw_Race == "Native American") %>%
    mutate(disprop_stops = prop_of_stops - na_pop_prop) %>%
    arrange(desc(total_num_stops))
# Out:
#    geography                          na_pop_prop raw_Race
# 1  Rolette County, North Dakota       77.3210098  Native American
# 2  Ramsey County, North Dakota         9.8132457  Native American
# 3  Ward County, North Dakota           1.3360694  Native American
# 4  Morton County, North Dakota         3.6329136  Native American
# 5  McLean County, North Dakota         7.1844249  Native American
# 6  Grand Forks County, North Dakota    2.5935430  Native American
# 7  Burleigh County, North Dakota       3.7915283  Native American
# 8  Bottineau County, North Dakota      2.4721134  Native American
# 9  Cass County, North Dakota           1.1680000  Native American
# 10 Pierce County, North Dakota         1.8657565  Native American
# 11 Towner County, North Dakota         2.1360070  Native American
# 12 Nelson County, North Dakota         1.3123360  Native American
# 13 McHenry County, North Dakota        0.6532577  Native American
# 14 Williams County, North Dakota       4.0885918  Native American
# 15 Stutsman County, North Dakota       1.5420383  Native American
# 16 Dunn County, North Dakota          10.9177592  Native American
# 17 Benson County, North Dakota        54.9749779  Native American
# 18 Stark County, North Dakota          0.9501188  Native American
# 19 Richland County, North Dakota       2.7946314  Native American
# 20 McKenzie County, North Dakota      17.7743110  Native American
# 21 Mountrail County, North Dakota     28.3799849  Native American
# 22 Barnes County, North Dakota         0.9371902  Native American
# 23 Traill County, North Dakota         1.0895134  Native American
# 24 Cavalier County, North Dakota       1.1568123  Native American
# 25 Kidder County, North Dakota         0.0000000  Native American
# 26 Walsh County, North Dakota          1.8264425  Native American
# 27 Wells County, North Dakota          0.2378687  Native American
# 28 Pembina County, North Dakota        2.3730225  Native American
# 29 Foster County, North Dakota         0.8318479  Native American
# 30 Slope County, North Dakota          0.0000000  Native American
# 31 Adams County, North Dakota          2.6911576  Native American
# 32 Billings County, North Dakota       0.5159959  Native American
# 33 Oliver County, North Dakota         4.2880704  Native American
# 34 Mercer County, North Dakota         2.9074482  Native American
# 35 Eddy County, North Dakota           4.1772152  Native American
# 36 Sargent County, North Dakota        0.5678885  Native American
# 37 Bowman County, North Dakota         1.1797578  Native American
# 38 LaMoure County, North Dakota        0.2188184  Native American
# 39 Dickey County, North Dakota         0.8084697  Native American
# 40 Renville County, North Dakota       0.5464481  Native American
# 41 Hettinger County, North Dakota      2.2892026  Native American
# 42 Emmons County, North Dakota         0.3176437  Native American
# 43 Golden Valley County, North Dakota  0.4390779  Native American
# 44 Burke County, North Dakota          1.1775362  Native American
# 45 Grant County, North Dakota          1.1007621  Native American
# 46 Divide County, North Dakota         1.5557476  Native American
# 47 Sheridan County, North Dakota       0.4487659  Native American
# 48 Ransom County, North Dakota         0.7518797  Native American
# 49 Griggs County, North Dakota         0.9446114  Native American
# 50 McIntosh County, North Dakota       0.5074302  Native American
# 51 Steele County, North Dakota         0.0000000  Native American
# 52 Sioux County, North Dakota         81.8036530  Native American
#    total_num_stops prop_of_stops disprop_stops
# 1  2733            65.0559391    -12.26507073
# 2  2305            13.4826860      3.66944029
# 3  1375             4.2476291      2.91155960
# 4  1127             7.6107509      3.97783737
# 5   755             7.5841286      0.39970365
# 6   687             2.2005830     -0.39295998
# 7   582             4.1055305      0.31400219
# 8   488            10.5650574      8.09294402
# 9   364             0.9052249     -0.26277506
# 10  361            14.9111937     13.04543718
# 11  286            23.0088496     20.87284258
# 12  261             6.2906725      4.97833649
# 13  238             6.8371158      6.18385808
# 14  238             1.1707989     -2.91779288
# 15  174             1.2041522     -0.33788609
# 16  170             3.5617012     -7.35605800
# 17  166             6.5225933    -48.45238460
# 18  164             1.0016491      0.05153029
# 19  162             2.0126724     -0.78195898
# 20  132             1.2199630    -16.55434794
# 21  103             2.0000000    -26.37998487
# 22   70             0.8357211     -0.10146912
# 23   69             1.0410380     -0.04847541
# 24   39             2.3493976      1.19258525
# 25   39             1.5892421      1.58924205
# 26   39             0.5047890     -1.32165350
# 27   39             1.2096774      0.97180872
# 28   33             0.8452869     -1.52773560
# 29   30             1.6666667      0.83481878
# 30   28             1.2313105      1.23131047
# 31   26             1.1866728     -1.50448487
# 32   26             0.9513355      0.43533966
# 33   24             1.8348624     -2.45320798
# 34   23             1.3577332     -1.54971499
# 35   22             5.9782609      1.80104568
# 36   22             0.8510638      0.28317534
# 37   20             0.7393715     -0.44038630
# 38   20             0.7454342      0.52661583
# 39   15             1.0948905      0.28642083
# 40   15             1.5511892      1.00474116
# 41   14             1.5053763     -0.78382625
# 42   11             1.0617761      0.74413240
# 43   10             0.9606148      0.52153686
# 44    9             1.2048193      0.02728305
# 45    9             1.0588235     -0.04193854
# 46    7             0.4260499     -1.12969771
# 47    7             3.0303030      2.58153714
# 48    6             0.2515723     -0.50030737
# 49    4             0.6514658     -0.29314562
# 50    3             1.0000000      0.49256977
# 51    3             0.3623188      0.36231884
# 52    2             9.5238095    -72.27984344

# %%
nd_data %>%
    group_by(geography, na_pop_prop, raw_Race) %>%
    summarize(
        total_num_stops = n()
    ) %>%
    mutate(prop_of_stops = (total_num_stops/sum(total_num_stops)) * 100) %>%
    filter(raw_Race == "Native American") %>%
    mutate(
        disprop_stops = prop_of_stops - na_pop_prop,
        STATEFP = "38"
    ) %>%
    separate(geography, into = c("county", "state"), sep = ", ", remove = FALSE) %>%
    write_csv("./data/nd_data_prop.csv")

# %% [markdown]
# ## Washington Analysis

# %%
#wa_data %>%
#    head()

# %%
?separate()
# Out:
# separate                 package:tidyr                 R Documentation
#
# s.
#
# n:
#
#      Given either regular expression or a vector of character
#      positions, ‘separate()’ turns a single character column into
#      multiple columns.
#
# e:
#
#      separate(data, col, into, sep = "[^[:alnum:]]+", remove = TRUE,
#        convert = FALSE, extra = "warn", fill = "warn", ...)
#
# s:
#
#     data: A data frame.
#
#      col: Column name or position. This is passed to
#           ‘tidyselect::vars_pull()’.
#
#           This argument is passed by expression and supports
#           quasiquotation (you can unquote column names or column
#           positions).
#
#     into: Names of new variables to create as character vector. Use
#           ‘NA’ to omit the variable in the output.
#
#      sep: Separator between columns.
#
#           If character, is interpreted as a regular expression. The
#           default value is a regular expression that matches any
#           sequence of non-alphanumeric values.
#
#           If numeric, interpreted as positions to split at. Positive
#           values start at 1 at the far-left of the string; negative
#           value start at -1 at the far-right of the string. The length
#           of ‘sep’ should be one less than ‘into’.
#
#   remove: If ‘TRUE’, remove input column from output data frame.
#
#  convert: If ‘TRUE’, will run ‘type.convert()’ with ‘as.is = TRUE’ on
#           new columns. This is useful if the component columns are
#           integer, numeric or logical.
#
#    extra: If ‘sep’ is a character vector, this controls what happens
#           when there are too many pieces. There are three valid
#           options:
#
#             • "warn" (the default): emit a warning and drop extra
#               values.
#
#             • "drop": drop any extra values without a warning.
#
#             • "merge": only splits at most ‘length(into)’ times
#
#     fill: If ‘sep’ is a character vector, this controls what happens
#           when there are not enough pieces. There are three valid
#           options:
#
#             • "warn" (the default): emit a warning and fill from the
#               right
#
#             • "right": fill with missing values on the right
#
#             • "left": fill with missing values on the left
#
#      ...: Additional arguments passed on to methods.
#
# o:
#
#      ‘unite()’, the complement, ‘extract()’ which uses regular
#      expression capturing groups.
#
# s:
#
#      library(dplyr)
#      df <- data.frame(x = c(NA, "a.b", "a.d", "b.c"))
#      df %>% separate(x, c("A", "B"))
#
#      # If you just want the second variable:
#      df %>% separate(x, c(NA, "B"))
#
#      # If every row doesn't split into the same number of pieces, use
#      # the extra and fill arguments to control what happens
#      df <- data.frame(x = c("a", "a b", "a b c", NA))
#      df %>% separate(x, c("a", "b"))
#      # The same behaviour drops the c but no warnings
#      df %>% separate(x, c("a", "b"), extra = "drop", fill = "right")
#      # Another option:
#      df %>% separate(x, c("a", "b"), extra = "merge", fill = "left")
#      # Or you can keep all three
#      df %>% separate(x, c("a", "b", "c"))
#
#      # If only want to split specified number of times use extra = "merge"
#      df <- data.frame(x = c("x: 123", "y: error: 7"))
#      df %>% separate(x, c("key", "value"), ": ", extra = "merge")
#
#      # Use regular expressions to separate on multiple characters:
#      df <- data.frame(x = c(NA, "a?b", "a.d", "b:c"))
#      df %>% separate(x, c("A","B"), sep = "([\\.\\?\\:])")
#
#      # convert = TRUE detects column classes
#      df <- data.frame(x = c("a:1", "a:2", "c:4", "d", NA))
#      df %>% separate(x, c("key","value"), ":") %>% str
#      df %>% separate(x, c("key","value"), ":", convert = TRUE) %>% str
#
#      # Argument col can take quasiquotation to work with strings
#      var <- "x"
#      df %>% separate(!!var, c("key","value"), ":")
